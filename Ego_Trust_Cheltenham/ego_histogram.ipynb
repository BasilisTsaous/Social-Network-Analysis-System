# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('FINAL_TRUST.csv')

plt.hist(data['TRUST'])
plt.title('Ego Trust Histogram')
plt.xlabel('Trust')
plt.ylabel('Number of Pairs')
plt.show()

# %%
import pandas as pd

data = pd.read_csv('FINAL_TRUST.csv')

new_data = data.sort_values('TRUST', ascending = False)
#new_data.to_csv('Sorted Users.csv', index=False)

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Sorted Users.csv')

plt.hist(data['TRUST'])
plt.title('Ego Trust Histogram')
plt.xlabel('Trust')
plt.ylabel('Number of Users')
plt.show()
