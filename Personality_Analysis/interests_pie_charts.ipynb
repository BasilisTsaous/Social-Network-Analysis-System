# %%
import pandas as pd
import matplotlib.pyplot as plt

f1 = pd.read_csv('user_interests.csv')

df1 = f1.groupby(['Music']).count()['user_id']

df1.plot(kind='pie', subplots=True, shadow = True, startangle=90, figsize=(6,6), autopct='%1.1f%%')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

f2 = pd.read_csv('user_interests.csv')

df2 = f2.groupby(['Movies']).count()['user_id']

df2.plot(kind='pie', subplots=True, shadow = True, startangle=90, figsize=(6,6), autopct='%1.1f%%')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

f3 = pd.read_csv('user_interests.csv')

df3 = f3.groupby(['Musical instruments']).count()['user_id']

df3.plot(kind='pie', subplots=True, shadow = True, startangle=90, figsize=(6,6), autopct='%1.1f%%')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

f4 = pd.read_csv('user_interests.csv')

df4 = f4.groupby(['Fun with friends']).count()['user_id']

df4.plot(kind='pie', subplots=True, shadow = True, startangle=90, figsize=(6,6), autopct='%1.1f%%')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

f5 = pd.read_csv('user_interests.csv')

df5 = f5.groupby(['Internet']).count()['user_id']

df5.plot(kind='pie', subplots=True, shadow = True, startangle=90, figsize=(6,6), autopct='%1.1f%%')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

f7 = pd.read_csv('user_interests.csv')

df7 = f7.groupby(['Countryside, outdoors']).count()['user_id']

df7.plot(kind='pie', subplots=True, shadow = True, startangle=90, figsize=(6,6), autopct='%1.1f%%')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

f8 = pd.read_csv('user_interests.csv')

df8 = f8.groupby(['Adrenaline sports']).count()['user_id']

df8.plot(kind='pie', subplots=True, shadow = True, startangle=90, figsize=(6,6), autopct='%1.1f%%')

plt.show()
